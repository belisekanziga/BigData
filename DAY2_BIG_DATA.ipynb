# %%
import pandas as pd
import numpy as np

# %%
age=np.array([10,20,30,40,50,60,70,80])
name=np.array(['alice','ange','bebe','alice','olive','alice','def','elie'])
df=pd.DataFrame({'age':age,'name':name})

# %%
df
# Out:
#    age   name
# 0   10  alice
# 1   20   ange
# 2   30   bebe
# 3   40  alice
# 4   50  olive
# 5   60  alice
# 6   70    def
# 7   80   elie

# %%
df[df['age']>25]
# Out:
#    age   name
# 2   30   bebe
# 3   40  alice
# 4   50  olive
# 5   60  alice
# 6   70    def
# 7   80   elie

# %%
df[df['name']=='alice']
# Out:
#    age   name
# 0   10  alice
# 3   40  alice
# 5   60  alice

# %%
df[(df['age']>25) & (df['name']=='alice')]
# Out:
#    age   name
# 3   40  alice
# 5   60  alice

# %%
df[(df['age']>20) | (df['age']>30)]
# Out:
#    age   name
# 2   30   bebe
# 3   40  alice
# 4   50  olive
# 5   60  alice
# 6   70    def
# 7   80   elie

# %%
df['age']=df['age']+1

# %%
df
# Out:
#    age   name
# 0   11  alice
# 1   21   ange
# 2   31   bebe
# 3   41  alice
# 4   51  olive
# 5   61  alice
# 6   71    def
# 7   81   elie

# %%
df['newcol']=df['age']*2

# %%
df
# Out:
#    age   name  newcol
# 0   11  alice      22
# 1   21   ange      42
# 2   31   bebe      62
# 3   41  alice      82
# 4   51  olive     102
# 5   61  alice     122
# 6   71    def     142
# 7   81   elie     162

# %%
df.rename(columns={'newcol':'marks'})
# Out:
#    age   name  marks
# 0   11  alice     22
# 1   21   ange     42
# 2   31   bebe     62
# 3   41  alice     82
# 4   51  olive    102
# 5   61  alice    122
# 6   71    def    142
# 7   81   elie    162

# %%
df.value_counts()
# Out:
# age  name   newcol
# 11   alice  22        1
# 21   ange   42        1
# 31   bebe   62        1
# 41   alice  82        1
# 51   olive  102       1
# 61   alice  122       1
# 71   def    142       1
# 81   elie   162       1
# dtype: int64

# %%
df.drop('newcol',axis=1)
# Out:
#    age   name
# 0   11  alice
# 1   21   ange
# 2   31   bebe
# 3   41  alice
# 4   51  olive
# 5   61  alice
# 6   71    def
# 7   81   elie

# %%
df.sort_values('age')
# Out:
#    age   name  newcol
# 0   11  alice      22
# 1   21   ange      42
# 2   31   bebe      62
# 3   41  alice      82
# 4   51  olive     102
# 5   61  alice     122
# 6   71    def     142
# 7   81   elie     162

# %%
df.sort_values(['age'],ascending=False)
# Out:
#    age   name  newcol
# 7   81   elie     162
# 6   71    def     142
# 5   61  alice     122
# 4   51  olive     102
# 3   41  alice      82
# 2   31   bebe      62
# 1   21   ange      42
# 0   11  alice      22

# %%
df.groupby('name').mean()#group by name and make mean of each
# Out:
#              age      newcol
# name
# alice  37.666667   75.333333
# ange   21.000000   42.000000
# bebe   31.000000   62.000000
# def    71.000000  142.000000
# elie   81.000000  162.000000
# olive  51.000000  102.000000

# %%
df['name'].value_counts()#count unique value
# Out:
# alice    3
# ange     1
# bebe     1
# olive    1
# def      1
# elie     1
# Name: name, dtype: int64

# %%
df.isnull()
# Out:
#      age   name  newcol
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False
# 7  False  False   False

# %%
df.dropna()
# Out:
#    age   name  newcol
# 0   11  alice      22
# 1   21   ange      42
# 2   31   bebe      62
# 3   41  alice      82
# 4   51  olive     102
# 5   61  alice     122
# 6   71    def     142
# 7   81   elie     162

# %%
df.fillna(0)
# Out:
#    age   name  newcol
# 0   11  alice      22
# 1   21   ange      42
# 2   31   bebe      62
# 3   41  alice      82
# 4   51  olive     102
# 5   61  alice     122
# 6   71    def     142
# 7   81   elie     162

# %%
df['age'].fillna(df['age'].mean())
# Out:
# 0    11
# 1    21
# 2    31
# 3    41
# 4    51
# 5    61
# 6    71
# 7    81
# Name: age, dtype: int64

# %%
df1 = pd.DataFrame({'key':['A','B','C'],'value1':[1,2,3]})

# %%
df2=pd.DataFrame({'key':['A','B','C'],'value2':[4,5,6]})

# %%
df1,df2
# Out:
# (  key  value1
#  0   A       1
#  1   B       2
#  2   C       3,
#    key  value2
#  0   A       4
#  1   B       5
#  2   C       6)

# %%
pd.concat([df1,df2],axis=0)
# Out:
#   key  value1  value2
# 0   A     1.0     NaN
# 1   B     2.0     NaN
# 2   C     3.0     NaN
# 0   A     NaN     4.0
# 1   B     NaN     5.0
# 2   C     NaN     6.0

# %%
pd.concat([df1,df2],axis=1)
# Out:
#   key  value1 key  value2
# 0   A       1   A       4
# 1   B       2   B       5
# 2   C       3   C       6

# %%
pd.merge(df1,df2,on='key',how='inner')
# Out:
#   key  value1  value2
# 0   A       1       4
# 1   B       2       5
# 2   C       3       6

# %%
pd.merge(df1,df2,on='key',how='left')
# Out:
#   key  value1  value2
# 0   A       1       4
# 1   B       2       5
# 2   C       3       6

# %%
pd.merge(df1,df2,on='key',how='right')
# Out:
#   key  value1  value2
# 0   A       1       4
# 1   B       2       5
# 2   C       3       6

# %%
df1.join(df2.set_index('key'),on='key',how='inner')
# Out:
#   key  value1  value2
# 0   A       1       4
# 1   B       2       5
# 2   C       3       6

# %%
df.corr()
# Out:
# /tmp/ipykernel_7099/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#         age  newcol
# age     1.0     1.0
# newcol  1.0     1.0

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
df[~df.duplicated()]
# Out:
#    age   name  newcol
# 0   11  alice      22
# 1   21   ange      42
# 2   31   bebe      62
# 3   41  alice      82
# 4   51  olive     102
# 5   61  alice     122
# 6   71    def     142
# 7   81   elie     162

# %%
df.isna()
# Out:
#      age   name  newcol
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False
# 7  False  False   False

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#    age   name  newcol
# 0   11  alice      22
# 1   21   ange      42
# 2   31   bebe      62
# 3   41  alice      82
# 4   51  olive     102
# 5   61  alice     122
# 6   71    def     142
# 7   81   elie     162

# %%
my_array = np.array([2,3,4])
my_array.ndim
# Out:
# 1

# %%
my_array = np.array([[2,3,4]])
my_array.ndim
# Out:
# 2

# %%
zoro=np.zeros((3,2))

# %%
zoro
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
zoro.ndim
# Out:
# 2

# %%
my_array = np.array([[[2,3,4]]])
my_array.ndim
# Out:
# 3

# %%
# we can found ndim as number of dimension for numpy and it is number of brackets

# %%
my_array1= np.array([2,3,4])
my_array2= np.array([2,3,4])
np.vstack((my_array1,my_array2))
# Out:
# array([[2, 3, 4],
#        [2, 3, 4]])

# %%
np.hstack((my_array1,my_array2))#concatinate
# Out:
# array([2, 3, 4, 2, 3, 4])

# %%
np.random.randn(2,3).astype('int')
# Out:
# array([[1, 0, 0],
#        [0, 1, 0]])
